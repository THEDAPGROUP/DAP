# %%
# Mysql connection 

from sqlalchemy import create_engine
import pymysql
import pandas as pd

sql_engine = create_engine('mysql+pymysql://root:root@localhost', pool_recycle=3600)
conn = sql_engine.connect()

sdf = pd.read_sql("select * from dap_ca.Stocks", conn);

# %%
sdf.shape
# Out:
# (6335, 11)

# %%
sdf.head()
# Out:
#    stock_id   symbol   price  pchange  prev_close    open  day_range_open  \
# 0         1  ADA-USD  1.2225  -0.0277      1.2384  1.2384          1.1956
# 1         2  ADA-USD  1.2243  -0.0249      1.2384  1.2384          1.1956
# 2         3  ADA-USD  1.2236  -0.0267      1.2384  1.2384          1.1956
# 3         4  ADA-USD  1.2232  -0.0263      1.2384  1.2384          1.1956
# 4         5  ADA-USD  1.2208  -0.0273      1.2384  1.2384          1.1956
#
#    day_range_close        volume market_cap                date
# 0           1.2587  1.387109e+09     41.76B 2021-12-17 23:21:09
# 1           1.2587  1.388174e+09    41.823B 2021-12-17 23:23:10
# 2           1.2587  1.386621e+09    41.796B 2021-12-17 23:25:11
# 3           1.2587  1.386079e+09    41.784B 2021-12-17 23:27:12
# 4           1.2587  1.385167e+09    41.701B 2021-12-17 23:29:13

# %%
sdf.plot.line(subplots=True, layout=(3,3), figsize=(10, 10))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# we can see there are multiple duplicates in date, so we can get rid of them.
sdf = sdf.drop_duplicates(subset='date', keep="last")
sdf.shape
# Out:
# (6249, 11)

# %%
# for our analysis we are going to focus on price
# first we will check if the price is stationary

from statsmodel.tsa.stattools
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e37d12493dbb> in <module>
# ----> 1 plt.figure(figsize=(10,6))
#       2 plt.grid(True)
#       3 plt.xlabel('Dates')
#       4 plt.ylabel('Close Prices')
#       5 plt.plot(sbin['close'])
#
# NameError: name 'plt' is not defined
